# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Đường dẫn ảnh
my_path = 'C:\\Users\\taithanhnguyen\\OneDrive - dntu.edu.vn\\Desktop\\ComputerVision\\Img\\04.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x357>

# %%
# Định vị khu vực cắt
region = (65, 75, 200, 180)
# Cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=135x105>

# %%
# Dán
# Xác định vị trí cần dán
paste_position = (50, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x357>
