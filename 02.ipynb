# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Thư mục chứa hình ảnh
my_dir = 'C:\\Users\\taithanhnguyen\\OneDrive - dntu.edu.vn\\Desktop\\ComputerVision\\Img'

# %%
# Đọc nhiều ảnh
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (626, 639)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x639>
# (275, 350)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x350>
# (635, 638)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=635x638>
# (224, 357)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x357>
