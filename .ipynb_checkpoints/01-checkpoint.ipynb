# %%
# Import lớp Image
from PIL import Image

# %%
# Thư mục chứa hình ảnh
dir = 'C:\\Users\\taithanhnguyen\\OneDrive - dntu.edu.vn\\Desktop\\omputerVision\\Img'

# %%
# Đường dẫn đến hình ảnh
image_path = dir +'/01.jpg'
print(image_path)
# Out:
# C:\Users\taithanhnguyen\OneDrive - dntu.edu.vn\Documents\ComputerVision\Img/01.jpg

# %%
# Sử dụng Image.open() đọc ảnh
img01 = Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x639>
