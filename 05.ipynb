# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Đường dẫn ảnh
my_path = 'C:\\Users\\taithanhnguyen\\OneDrive - dntu.edu.vn\\Desktop\\ComputerVision\\Img\\04.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x357>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x357>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x357>

# %%
# Transpose ảnh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=357x224>

# %%
# Transpose ảnh
transposed_image = transposed_image.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x357>
